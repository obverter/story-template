# %%
import pandas as pd
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.tmz.com'
req = requests.get(url)
doc = BeautifulSoup(req.text)

# %%
stories = {}
for trash in doc.select('header > a > h2'):
        raw = trash.text
        story = {
                "headline": raw.strip().replace("\n", " ")
        }
        stories |= story
stories
# Out:
# {'headline': 'BTS Fans Can Live Like K-Pop Superstars In Same House BTS Filmed Reality Show'}

# %%
tmz = doc.select('header a h2')
tmz_timestamps = doc.select(".article")
stories = pd.DataFrame(columns=["timestamp", "headline"])
paragraphs = []
count = 0
for trash in enumerate(tmz):
    headline = tmz[count].text
    headline = headline.replace("\n", " ").upper()
    
    timestamp = tmz_timestamps[count].text.split('PT')[-20:]
    timestamp = timestamp[0][-20:]
    timestamp = timestamp.strip()
    
    story = {
        "timestamp": timestamp,
        "headline": headline
    }
    
    stories = stories.append(story, ignore_index=True)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/bean/Dropbox/code/_projects/tmz-poetry/notebooks/tmz-poetry.ipynb Cell 4 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/bean/Dropbox/code/_projects/tmz-poetry/notebooks/tmz-poetry.ipynb#ch0000013?line=5'>6</a> for trash in enumerate(tmz):
#       <a href='vscode-notebook-cell:/Users/bean/Dropbox/code/_projects/tmz-poetry/notebooks/tmz-poetry.ipynb#ch0000013?line=6'>7</a>     headline = tmz[count].text
# ----> <a href='vscode-notebook-cell:/Users/bean/Dropbox/code/_projects/tmz-poetry/notebooks/tmz-poetry.ipynb#ch0000013?line=7'>8</a>     headline = headline.replace("\n", " ").timestamper()
#      <a href='vscode-notebook-cell:/Users/bean/Dropbox/code/_projects/tmz-poetry/notebooks/tmz-poetry.ipynb#ch0000013?line=9'>10</a>     timestamp = tmz_timestamps[count].text.split('PT')[-20:]
#      <a href='vscode-notebook-cell:/Users/bean/Dropbox/code/_projects/tmz-poetry/notebooks/tmz-poetry.ipynb#ch0000013?line=10'>11</a>     timestamp = timestamp[0][-20:]
#
# AttributeError: 'str' object has no attribute 'timestamper'

# %%
pp = tmz_timestamps[0].text.split('PT')[-20:]
pp = pp[0][-20:]
pp = pp.strip()
pp
# Out:
# '7/26/2022 2:27 PM'

# %%
stories
# Out:
#             timestamp                                           headline
# 0   7/26/2022 2:27 PM   KEVIN HART SHAMES EX-NFLER OVER NUDIST COLONY...
# 1   7/26/2022 2:27 PM   TONY DOW 'LEAVE IT TO BEAVER' STAR STILL ALIV...
# 2   7/26/2022 2:27 PM   JIM HARBAUGH I'M WILLING TO RAISE MY PLAYERS'...
# 3   7/26/2022 2:27 PM   'RHONY' STAR SONJA MORGAN LISTS NYC TOWNHOUSE...
# 4   7/26/2022 2:27 PM   CALIFORNIA SOCCER PLAYER DIES FOLLOWING IN-GA...
# 5   7/26/2022 2:27 PM      PETSMART SUED YOUR GROOMERS KILLED MY DOG!!!
# 6   7/26/2022 2:27 PM   TACO BELL EMPLOYEE ALLEGEDLY THROWS BOILING H...
# 7   7/26/2022 2:27 PM   HELICOPTER TRAGEDY MAN DIES WALKING INTO BLAD...
# 8   7/26/2022 2:27 PM   LANA DEL REY GETS TRO AGAINST ALLEGED STALKER...
# 9   7/26/2022 2:27 PM   'RHOA' STAR SHEREE WHITFIELD DATING MARTELL H...
# 10  7/26/2022 2:27 PM   BRITTNEY GRINER SENDS MESSAGE TO WIFE IN COUR...
# 11  7/26/2022 2:27 PM   'SHAHS OF SUNSET' MIKE CHARGED WITH DOMESTIC ...
# 12  7/26/2022 2:27 PM   UKRAINIAN OLYMPIAN SELLS SILVER MEDAL TO FUND...
# 13  7/26/2022 2:27 PM   DANNY GARCIA I GOT A LEG UP ON JOSÉ BENAVIDEZ...
# 14  7/26/2022 2:27 PM   THE SILENT BELLA IN 'PITCH PERFECT' 'MEMBA HE...
# 15  7/26/2022 2:27 PM   BTS FANS CAN LIVE LIKE K-POP SUPERSTARS IN SA...

# %%
stories = pd.DataFrame(columns=['headline', 'timestamp', 'text'])
tmz = doc.select(".article")
paragraphs = []
count = 0
for count, p in enumerate(tmz):
    para = tmz[count].text
    para = para.strip().replace("\n", " ")
    paragraphs.append(para)
    
    headline = paragraphs[0].split("PT")
    
    text = headline[1]
    
    timestamp = headline[0][-20:]
    timestamp = timestamp.strip()
    
    headline = headline[0][:-20]
    headline = headline.split("  ")
    headline = headline[0].upper()
    
    story = {
        "headline": headline,
        "timestamp": timestamp,
        "text": text
    }
    stories = stories.append(story, ignore_index = True)
    count += 1
stories.head()
# print(headline)
# print(timestamp)
# print(test)

# %%
# Out:
# <article class="article" id="blogroll-8f15adb0-b7a8-455c-b529-20a6a07c3ad8">
# <div class="article__channel--legal"></div>
# <header class="article__header">
# <a class="article__header-link js-track-link" data-context='{"section":"main","name":"headline","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2022/07/26/petsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping/">
# <h2 class="article__header-title">
# <span class="article__hf1 text-uppercase h3">PetSmart Sued</span>
# <span class="article__hf2 text-uppercase h1">Your Groomers Killed My Dog!!!</span>
# </h2>
# </a>
# <h5 class="article__published-at">
# <ul class="social social--sm">
# <li>
# <div class="media-swipe media-swipe--blogroll">Exclusive</div>
# </li>
# <li class="social-item">
# <a aria-label="Share on Facebook" class="btn social__btn social__btn--sm social__btn--facebook js-track-link" data-context='{"section":"main","name":"facebook-header","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2022/07/26/petsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping/" onclick="window.open('http://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.tmz.com%2F2022%2F07%2F26%2Fpetsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping%2F%3Fadid%3Dshare-fb', '_blank', 'status=0,width=575,height=450');return false;">
# <span aria-label="Facebook" class="icon icon-facebook--white social__icon--facebook" role="img"></span>
# <span class="social__count">770</span>
# <span class="sr-only">shares</span>
# </a>
# </li>
# <li class="social-item">
# <a aria-label="Share on Twitter" class="btn social__btn social__btn--sm social__btn--twitter js-track-link" data-context='{"section":"main","name":"twitter-header","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2022/07/26/petsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping/" onclick="window.open('https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.tmz.com%2F2022%2F07%2F26%2Fpetsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping%2F%3Fadid%3Dshare-tw&amp;text=Dog%20Owner%20Sues%20PetSmart%2C%20Claims%20Staff%20Suffocated%20Pet%20During%20Nail%20Clipping&amp;via=TMZ&amp;related=HarveyLevinTMZ', '_blank', 'status=0,width=575,height=450');return false;">
# <span aria-label="Twitter" class="icon icon-sd icon-twitter--white" role="img"></span>
# </a>
# </li>
# </ul><!--/.social-->
#
#                                           7/26/2022 1:00 AM PT
#                                     </h5><!--/.article__posted-date-->
# </header>
# <div class="article__blocks">
# <section class="canvas-block canvas-block-blogroll canvas-video-block canvas-video-block-blogroll canvas-video-block--default canvas-block-is-first" id="cb-d024627936e37ebc2c3a94af78c3c336">
# <div class="video-block">
# <div class="embed-responsive embed-responsive-16by9">
# <div class="embed-responsive-item video-block__backdrop below" id="video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-progress-spinner">
# <div class="spinner video-block__spinner"></div>
# </div>
# <div class="embed-responsive-item video-block__image-holder" id="video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-image-holder">
# <button class="embed-responsive-item icon-video--shadow video-block__icon" id="video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-play-btn">
# <span class="sr-only">Play video content</span>
# </button>
# <img class="img-fluid" loading="lazy" src="https://imagez.tmz.com/image/ed/16by9/2022/07/25/ed019ca8dbf643ccbd4986dbd84b26bf_md.jpg"/>
# </div>
# <div class="embed-responsive-item embed-responsive-item--jwplayer invisible">
# <div class="video-portal" data-autoplay="false" data-muted="false" data-node-ref="tmz:video:a8f920d9-0459-4814-b33d-4c1b46482d06" id="jwplayer-video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561">
# </div>
# </div>
# </div>
# <footer class="media-footer video-block__media-footer" id="video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-footer">
# <span class="media-launch-text video-block__media-launch-text">SECURITY FOOTAGE</span>
# </footer>
# <span class="media-credit video-block__media-credit">AJ Ross</span>
# </div>
# <script type="application/ld+json">
#       {
#         "@context": "https://schema.org",
#         "@type": "VideoObject",
#         "name": "Dog Owner Sues PetSmart, Claims Staff Suffocated Pet During Nail Clipping",
#         "description": "A standard grooming appointment at a PetSmart turned into an emergency crisis -- one that resulted in the death of a pooch ... according to a new lawsuit.",
#                   "thumbnailUrl": [
#             "https://imagez.tmz.com/image/ed/4by3/2022/07/25/ed019ca8dbf643ccbd4986dbd84b26bf_xl.jpg",
#             "https://imagez.tmz.com/image/ed/1by1/2022/07/25/ed019ca8dbf643ccbd4986dbd84b26bf_xl.jpg",
#             "https://imagez.tmz.com/image/ed/16by9/2022/07/25/ed019ca8dbf643ccbd4986dbd84b26bf_xl.jpg"
#           ],
#                 "inLanguage": "en-US",
#         "datePublished": "2022-07-26T08:00:58Z",
#                   "duration": "PT2M50S",
#                 "uploadDate": "2022-07-25T18:53:46Z",
#         "dateCreated": "2022-07-25T18:53:46Z",
#         "dateModified": "2022-07-26T08:01:03Z",
#                 "width": "560",
#         "height": "315",
#                   "contentUrl": "https://ovp.tmz.com/video/8a/o/2022/07/25/8a9ca937517f4f5c91287b98325db33a.mp4",
#                           "embedUrl": "https://share.tmz.com/videos/2022-07-25-072522-pet-smart-1459441/",
#                 "author": {
#           "@type": "Person",
#           "name": "TMZ Staff"
#         },
#                 "publisher": {
#           "@type": "Organization",
#           "name": "TMZ",
#           "logo": {
#             "@type": "ImageObject",
#             "url": "https://static.tmz.com/tmz-web/img/tmz-logo-red-147x60-v1.png",
#             "height": 60,
#             "width": 147
#           }
#         }
#       }
#       </script>
# <script>
#       wbq.push(function renderVideoBlock() {
#         var page = window.TMZ.select(window.TMZ.selectors.getPage);
#         // there is a weird bug with iPhone 6+ on iOS 9.3.4 where the spinner gets revealed even after its
#         // event listener has been removed, so for now this stupid flag can correct for that.
#         var isResolved = false;
#         if (!page.isTurbolinksPreview) {
#           function displayPlayer(player) {
#             if (player.id === 'jwplayer-video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-player') {
#               player.getContainer().closest('.embed-responsive-item--jwplayer').classList.remove('invisible');
#               return;
#             }
#             // a fallback video
#             player.closest('.embed-responsive-item--jwplayer').classList.remove('invisible');
#           }
#           function fadeImageHolderAndFooter() {
#             var imageHolder = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-image-holder');
#             var footer = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-footer');
#             hideSpinner();
#             if (imageHolder) {
#               imageHolder.addEventListener('transitionend', removeImageHolder, { once: true });
#               imageHolder.classList.add('video-block__image-holder-fade');
#             }
#
#             if (footer && !footer.classList.contains('hidden')) {
#               footer.addEventListener('transitionend', removeFooter, { once: true });
#               footer.classList.add('video-block__media-footer-fade');
#             }
#           }
#           function removeImageHolder() {
#             var imageHolder = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-image-holder');
#             if (imageHolder) {
#               imageHolder.remove();
#             }
#           }
#           function removeFooter() {
#             var footer = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-footer');
#             if (footer) {
#               footer.classList.add('hidden');
#             }
#           }
#           function hideSpinner() {
#             var spinner = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-progress-spinner');
#             spinner.classList.add('below');
#             spinner.classList.remove('above');
#           }
#           function revealSpinner() {
#             if (isResolved) {
#               return;
#             }
#             var spinner = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-progress-spinner');
#             spinner.classList.add('above');
#             spinner.classList.remove('below');
#           }
#
#           window.TMZ.videos.observe(document.getElementById('jwplayer-video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561'), {
#                         onObserve: function() {
#               document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-play-btn').addEventListener('mousemove', revealSpinner, { once: true });
#             },
#             onResolve: function(player) {
#               isResolved = true;
#               var playButton = document.getElementById('video-player-a8f920d9-0459-4814-b33d-4c1b46482d06-147065561-play-btn');
#               playButton.removeEventListener('mousemove', revealSpinner);
#               playButton.addEventListener('click', function() {
#                 displayPlayer(player);
#                 player.play();
#                 removeImageHolder();
#                 removeFooter();
#                 window.TMZ.dispatch(window.TMZ.actions.clickLink(
#                   'https://www.tmz.com/videos/2022-07-25-072522-pet-smart-1459441/',
#                   null,
#                   'tmz:video:a8f920d9-0459-4814-b33d-4c1b46482d06',
#                   null,
#                   {
#                     section: 'blogroll',
#                     name: 'video',
#                     action: 'click'
#                   }
#                 ));
#               }, { once: true });
#               hideSpinner();
#             }
#                       });
#         }
#       });
#     </script>
# </section><!--/#cb-d024627936e37ebc2c3a94af78c3c336-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-967039fb4929bafd3c43b5d14ef5fcb7">
# <p>A standard grooming appointment at a PetSmart turned into an emergency crisis -- one that resulted in the death of a pooch ... according to a new lawsuit.</p>
# </section><!--/#cb-967039fb4929bafd3c43b5d14ef5fcb7-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-530a04dd5e87f1bdf64947bea6c5c3aa">
# <p><strong>AJ Ross</strong> is suing the pet store retailer over the 2020 death of her poodle, Kobe -- which happened after she dropped off her pooch for a nail clipping at a PetSmart in Pittsburgh, PA.</p>
# </section><!--/#cb-530a04dd5e87f1bdf64947bea6c5c3aa-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-aa7ff790cfc5a8311ae3a660671a493a">
# <p>In the lawsuit, she lays blame directly at the feet of the store's employees -- and adds, the store's own surveillance video is the most compelling evidence supporting her case.</p>
# </section><!--/#cb-aa7ff790cfc5a8311ae3a660671a493a-->
# <section class="canvas-block canvas-block-blogroll canvas-image-block canvas-image-block-blogroll canvas-image-block--default" id="cb-718b516295bcc23e4cd208f6638db325">
# <div class="image-block">
# <a class="js-click-image js-track-link image-lightbox-preview" data-container-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-context='{"section":"blogroll","name":"image"}' data-node-ref="tmz:image-asset:image_jpg_20220725_06b22adefe444a538b80aca706e9d745">
# <div class="img-wrapper">
# <div class="magnify-icon icon icon-lg">
# <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><defs></defs><path d="M10.5 0a9.5 9.5 0 016.91 16.02L23 21.76a1 1 0 11-1.44 1.4l-5.66-5.84A9.5 9.5 0 1110.5 0zm0 2a7.5 7.5 0 100 15 7.5 7.5 0 000-15zm0 3a1 1 0 011 1v2.5H14a1 1 0 010 2h-2.5V13a1 1 0 01-2 0v-2.5H7a1 1 0 010-2h2.5V6a1 1 0 011-1z"></path></svg>
# </div>
# <img alt="" class="img-fluid image-block__img-fluid img-aspect-auto" loading="lazy" src="https://imagez.tmz.com/image/06/4by3/2022/07/25/06b22adefe444a538b80aca706e9d745_md.jpg"/>
# </div>
# </a>
# </div>
# <script>
#       wbq.push(function preloadImage() {
#         window.TMZ.dispatch(window.TMZ.actions.loadNode({"_schema":"pbj:tmz:dam:node:image-asset:1-0-0","_id":"image_jpg_20220725_06b22adefe444a538b80aca706e9d745","status":"published","etag":"2908c9931e4073a3cd7a9d1f4662509d","created_at":"1658775783938200","title":"0725-AJ and Kobe-ig2.jpg","mime_type":"image\/jpeg","file_size":"728632","file_etag":"132de363d6185c190eea4f554a9392a5","gallery_seq":0,"width":1074,"height":806}));
#       });
#     </script>
# </section><!--/#cb-718b516295bcc23e4cd208f6638db325-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-86b4317c2591cb789d5c5dbe9b69762e">
# <p>The footage is tough to watch. You see Ross drop the dog off with the staff, having already placed a muzzle on its mouth, and then leave. The workers then take it to the back and lift it onto a table.</p>
# </section><!--/#cb-86b4317c2591cb789d5c5dbe9b69762e-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-9b9f8f9064c2fc895c31f812fff0ca46">
# <p>That's where things get wild ... it appears the employees put 2 different harnesses around Kobe's neck -- one from the top and one from the bottom -- seemingly to keep the dog in place while they try to work on its paws.</p>
# </section><!--/#cb-9b9f8f9064c2fc895c31f812fff0ca46-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-edc658ff5c2dc0aab2d598d84101336f">
# <p>Kobe thrashes around, and they eventually tip the poodle over on its side for easier access ... at least that's what Ross claims in her suit.</p>
# </section><!--/#cb-edc658ff5c2dc0aab2d598d84101336f-->
# <section class="canvas-block canvas-block-blogroll canvas-image-block canvas-image-block-blogroll canvas-image-block--default" id="cb-8e4d9fea4a60945b2761bc295cce1d22">
# <div class="image-block">
# <a class="js-click-image js-track-link image-lightbox-preview" data-container-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-context='{"section":"blogroll","name":"image"}' data-node-ref="tmz:image-asset:image_jpg_20220725_26e039ccc6274c24a7e57015bf21a7a2">
# <div class="img-wrapper">
# <div class="magnify-icon icon icon-lg">
# <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><defs></defs><path d="M10.5 0a9.5 9.5 0 016.91 16.02L23 21.76a1 1 0 11-1.44 1.4l-5.66-5.84A9.5 9.5 0 1110.5 0zm0 2a7.5 7.5 0 100 15 7.5 7.5 0 000-15zm0 3a1 1 0 011 1v2.5H14a1 1 0 010 2h-2.5V13a1 1 0 01-2 0v-2.5H7a1 1 0 010-2h2.5V6a1 1 0 011-1z"></path></svg>
# </div>
# <img alt="" class="img-fluid image-block__img-fluid img-aspect-auto" loading="lazy" src="https://imagez.tmz.com/image/26/4by3/2022/07/25/26e039ccc6274c24a7e57015bf21a7a2_md.jpg"/>
# </div>
# </a>
# </div>
# <script>
#       wbq.push(function preloadImage() {
#         window.TMZ.dispatch(window.TMZ.actions.loadNode({"_schema":"pbj:tmz:dam:node:image-asset:1-0-0","_id":"image_jpg_20220725_26e039ccc6274c24a7e57015bf21a7a2","status":"published","etag":"7248193aa3e28654b11823e21160a037","created_at":"1658775785223175","title":"0725-AJ and Kobe-ig1.jpg","mime_type":"image\/jpeg","file_size":"565710","file_etag":"4ca9dfb66422281797c753a8673b2482","gallery_seq":0,"width":1074,"height":806}));
#       });
#     </script>
# </section><!--/#cb-8e4d9fea4a60945b2761bc295cce1d22-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-2f283b2a1d2558bffdda23520b91937d">
# <p>Soon enough, the dog goes limp and the workers try waking it up, to no avail. Ross says when she returned a mere 10 minutes later, she discovered her dog was dead -- and she believes the way the PetSmart employees harnessed Kobe during the nail clipping caused the dog to lose consciousness and die.</p>
# </section><!--/#cb-2f283b2a1d2558bffdda23520b91937d-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-d2428b1b5bdc7649e8693122bc7014f8">
# <p>According to documents, Ashley claims PetSmart has allowed this to happen to other pets over the years -- upwards of 47 have allegedly been killed by PetSmart groomers since 2009 -- and now she wants damages.</p>
# </section><!--/#cb-d2428b1b5bdc7649e8693122bc7014f8-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default" data-context='{"section":"blogroll","name":"text_block"}' id="cb-66064579bf21b9ac0256bd5df01a7dc7">
# <p>A rep for PetSmart tells TMZ ... "All of us are heartbroken by and truly sorry for the loss of Kobe. Following this terrible accident in 2020, we immediately launched an internal investigation and cooperated with the authorities involved. In response, we terminated the associates who violated our pet safety policies and did not meet our high standards of care."</p>
# </section><!--/#cb-66064579bf21b9ac0256bd5df01a7dc7-->
# <section class="canvas-block canvas-block-blogroll canvas-text-block canvas-text-block-blogroll canvas-text-block--default canvas-block-is-last" data-context='{"section":"blogroll","name":"text_block"}' id="cb-53f1721ae32f57c8644bb3e42979af52">
# <p>"We proudly perform more than 13 million grooming services per year and the actions of these two associates do not represent the standard of care provided by our more than 10,000 salon associates."</p>
# </section><!--/#cb-53f1721ae32f57c8644bb3e42979af52-->
# </div><!--/.article__blocks-->
# <div class="row">
# <div class="col-12">
# <ul class="social social--blogroll">
# <li class="social__item social__item--3items">
# <a class="btn social__btn social__btn--facebook js-track-link" data-context='{"section":"main","name":"facebook-footer","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2022/07/26/petsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping/" onclick="window.open('https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.tmz.com%2F2022%2F07%2F26%2Fpetsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping%2F%3Fadid%3Dshare-fb', '_blank', 'status=0,width=575,height=450');return false;">
# <span aria-hidden="true" aria-label="Facebook" class="icon icon-lg icon-facebook--white social__icon--facebook" role="img"></span>
#                     Share<span class="social__hide-sm"> on Facebook</span>
# </a>
# </li>
# <li class="social__item social__item--3items">
# <a class="btn social__btn social__btn--twitter js-track-link" data-context='{"section":"main","name":"twitter-footer","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2022/07/26/petsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping/" onclick="window.open('https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.tmz.com%2F2022%2F07%2F26%2Fpetsmart-sued-pet-owner-claims-staff-suffocated-dog-nail-clipping%2F%3Fadid%3Dshare-tw&amp;text=Dog%20Owner%20Sues%20PetSmart%2C%20Claims%20Staff%20Suffocated%20Pet%20During%20Nail%20Clipping&amp;via=TMZ&amp;related=HarveyLevinTMZ', '_blank', 'status=0,width=575,height=450');return false;">
# <span aria-hidden="true" aria-label="Twitter" class="icon icon-lg icon-twitter--white social__icon--twitter" role="img"></span>
#                     TWEET<span class="social__hide-sm"> This</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <section class="related-articles">
# <header class="card-section-header related-articles__card-section-header">
# <h3 class="card-section-title related-articles__card-section-title">
#                   Related Articles
#                 </h3>
# </header>
# <div class="row related-articles__row">
# <div class="col related-articles__col">
# <article class="related-articles__card">
# <a class="related-articles__card-link js-track-link" data-context='{"section":"main","name":"related-article","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2021/11/30/dead-dog-found-trash-lax/">
# <div class="related-articles__card-img embed-responsive">
# <div class="embed-responsive-item">
# <img alt="Dead Dog Found in LAX Trash Bin" class="img-fluid" loading="lazy" src="https://imagez.tmz.com/image/2e/16by9/2021/12/01/2efeff54957b4d999d20b3ea7c7c343d_xs.jpg"/>
# </div>
# </div>
# <div class="related-articles__card-body">
# <h4 class="related-articles__card-title">
#                             Dead Dog Found in LAX Trash Bin
#                           </h4>
# </div>
# </a>
# </article>
# </div>
# <div class="col related-articles__col">
# <article class="related-articles__card">
# <a class="related-articles__card-link js-track-link" data-context='{"section":"main","name":"related-article","pos":3}' data-node-ref="tmz:article:8f15adb0-b7a8-455c-b529-20a6a07c3ad8" data-widget-ref="tmz:blogroll-widget:39cc321d-66b9-57e0-816e-f745a6fcb489" href="https://www.tmz.com/2022/01/04/dog-dies-southwest-flight-family-blames-airline/">
# <div class="related-articles__card-img embed-responsive">
# <div class="embed-responsive-item">
# <img alt="Dog Dies on Southwest Flight, Family Blaming Airline" class="img-fluid" loading="lazy" src="https://imagez.tmz.com/image/f4/16by9/2022/01/03/f4d4df9f8378400b866f5c91bf2e3a7b_xs.jpg"/>
# </div>
# </div>
# <div class="related-articles__card-body">
# <h4 class="related-articles__card-title">
#                             Dog Dies on Southwest Flight, Family Blaming Airline
#                           </h4>
# </div>
# </a>
# </article>
# </div>
# </div>
# </section>
# <section class="tag-cloud">
# <ul class="tag-cloud__list-group">
# <a class="tag-cloud__list-group-item js-track-link" data-context='{"section":"main","name":"tag-cloud","pos":3}' href="https://www.tmz.com/categories/pets/">
#                     Pets
#                   </a>
# <a class="tag-cloud__list-group-item js-track-link" data-context='{"section":"main","name":"tag-cloud","pos":3}' href="https://www.tmz.com/categories/rip/">
#                     RIP
#                   </a>
# <a class="tag-cloud__list-group-item js-track-link" data-context='{"section":"main","name":"tag-cloud","pos":3}' href="https://www.tmz.com/categories/money/">
#                     Money
#                   </a>
# <a class="tag-cloud__list-group-item js-track-link" data-context='{"section":"main","name":"tag-cloud","pos":3}' href="https://www.tmz.com/categories/animals/">
#                     Animals
#                   </a>
# <a class="tag-cloud__list-group-item js-track-link" data-context='{"section":"main","name":"tag-cloud","pos":3}' href="https://www.tmz.com/categories/exclusive/">
#                     Exclusive
#                   </a>
# <a class="tag-cloud__list-group-item js-track-link" data-context='{"section":"main","name":"tag-cloud","pos":3}' href="https://www.tmz.com/categories/fairly-legal/">
#                     Fairly Legal
#                   </a>
# </ul>
# </section><!--/.tag-cloud-->
# </article>

# %%
story['text'] = story['text'].strip()

# %%
story['text'] = story

# %%
stories = stories.append(story, ignore_index=True)
stories.head()
# Out:
# /var/folders/m9/kw6252cj3lqgftmsg97nw4z80000gn/T/ipykernel_70490/1767405145.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stories = stories.append(story, ignore_index=True)
#                                         headline          timestamp  \
# 0  TONY DOW 'LEAVE IT TO BEAVER' STAR DEAD AT 77  7/26/2022 8:56 AM
# 1  TONY DOW 'LEAVE IT TO BEAVER' STAR DEAD AT 77  7/26/2022 8:56 AM
#
#                                                 text
# 0  {'headline': 'TONY DOW 'LEAVE IT TO BEAVER' ST...
# 1  {'headline': 'TONY DOW 'LEAVE IT TO BEAVER' ST...

# %%
import sidetable

# %%
def generalize(ser, match_name, default=None, regex=False, case=False):
    """ Search a series for text matches.
    Based on code from https://www.metasnake.com/blog/pydata-assign.html

    ser: pandas series to search
    match_name: tuple containing text to search for and text to use for normalization
    default: If no match, use this to provide a default value, otherwise use the original text
    regex: Boolean to indicate if match_name contains a  regular expression
    case: Case sensitive search

    Returns a pandas series with the matched value

    """
    seen = None
    for match, name in match_name:
        mask = ser.str.contains(match, case=case, regex=regex)
        if seen is None:
            seen = mask
        else:
            seen |= mask
        ser = ser.where(~mask, name)
    ser = ser.where(seen, default) if default else ser.where(seen, ser.values)
    return ser
